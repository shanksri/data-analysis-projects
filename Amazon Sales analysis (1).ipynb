# %%
import numpy as np

# %%
import pandas as pd

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname,filename))

# %%
df = pd.read_csv(r'C:\Users\shash\Downloads\amazon.csv')

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
df.describe()
# Out:
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B07JW9H4J1  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        actual_price discount_percentage rating rating_count  \
# count          1465                1465   1465         1463
# unique          449                  92     28         1143
# ...

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df.describe()
# Out:
#         product_id                                       product_name  \
# count         1463                                               1463
# unique        1349                                               1335
# top     B07JW9H4J1  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1463             1463
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  231               52
#
#        actual_price discount_percentage rating rating_count  \
# count          1463                1463   1463         1463
# unique          449                  92     28         1143
# ...

# %%
rating_count = []
for i in df['rating_count'].values:
    rating_count.append(i.replace(',',''))#removing the ',' present in values

# %%
df['rating_count']=rating_count

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2        24269
# ...

# %%
discounted_price = []
for i in df['discounted_price'].values:
    discounted_price.append(float(i[1:].replace(',','')))
df['discounted_price']=discounted_price

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2        24269
# ...

# %%
actual_price=[]
for i in df['actual_price'].values:
    actual_price.append(float(i[1:].replace(',','')))
df['actual_price']=actual_price

# %%
discount_percentage = []
for i in df['discount_percentage'].values:
    discount_percentage.append(int(i[:-1])/100)
df['discount_percentage']=discount_percentage

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage rating rating_count  \
# 0        1099.0                 0.64    4.2        24269
# ...

# %%
'''EDA'''
# Out:
# 'EDA'

# %%
unique_category = []
for i in df['category'].values:
    unique_category+=(i.split('|'))

# %%
unique_category = list(set(unique_category))

# %%
unique_category
# Out:
# ['MemoryCards',
#  'Smartphones&BasicMobiles',
#  'WoodenPencils',
#  'DustCovers',
#  'Cables',
#  'Chargers',
#  'BluetoothSpeakers',
#  'HalogenHeaters',
#  'Bags,Cases&Sleeves',
#  'RetractableBallpointPens',
#  'HandheldBags',
#  'HandBlenders',
#  'MultimediaSpeakerSystems',
#  'USBGadgets',
#  'CoffeePresses',
#  'SpeakerCables',
#  'Cases&Covers',
#  'CameraPrivacyCovers',
#  'WallChargers',
#  'InternalSolidStateDrives',
#  'GamingKeyboards',
#  'HomeImprovement',
#  'DisposableBatteries',
#  'Paints',
#  'Computers&Accessories',
#  'DigitalBathroomScales',
#  'MeasuringSpoons',
#  'PedestalFans',
#  'Paper',
#  'Stands',
#  'Décor',
#  'LaundryBaskets',
#  'Tripods',
#  'PenDrives',
#  'BasicMobiles',
#  'Heating,Cooling&AirQuality',
#  'Lapdesks',
#  'WaterHeaters&Geysers',
#  'Keyboards,Mice&InputDevices',
#  'StandMixers',
#  'Mobiles&Accessories',
#  'Coffee,Tea&Espresso',
#  'LaptopChargers&PowerSupplies',
#  'Components',
#  'OutdoorSpeakers',
# ...

# %%
len(unique_category)
# Out:
# 317

# %%
for j in df.values:
    print(j[2])
# Out:
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables
# Computers&Accessories|NetworkingDevices|NetworkAdapters|WirelessUSBAdapters
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables
# ...

# %%
data = []
for i in unique_category:
    c=0
    for j in df['category']:
        if i in j:
            c+=1
    data.append([i,c])

# %%
data
# Out:
# [['MemoryCards', 14],
#  ['Smartphones&BasicMobiles', 77],
#  ['WoodenPencils', 1],
#  ['DustCovers', 2],
#  ['Cables', 270],
#  ['Chargers', 53],
#  ['BluetoothSpeakers', 6],
#  ['HalogenHeaters', 2],
#  ['Bags,Cases&Sleeves', 2],
#  ['RetractableBallpointPens', 2],
#  ['HandheldBags', 1],
#  ['HandBlenders', 19],
#  ['MultimediaSpeakerSystems', 1],
#  ['USBGadgets', 5],
#  ['CoffeePresses', 1],
#  ['SpeakerCables', 1],
#  ['Cases&Covers', 4],
#  ['CameraPrivacyCovers', 3],
#  ['WallChargers', 16],
#  ['InternalSolidStateDrives', 3],
#  ['GamingKeyboards', 3],
#  ['HomeImprovement', 2],
#  ['DisposableBatteries', 7],
#  ['Paints', 3],
#  ['Computers&Accessories', 451],
#  ['DigitalBathroomScales', 1],
#  ['MeasuringSpoons', 3],
#  ['PedestalFans', 1],
#  ['Paper', 27],
#  ['Stands', 20],
#  ['Décor', 6],
#  ['LaundryBaskets', 13],
#  ['Tripods', 6],
#  ['PenDrives', 10],
#  ['BasicMobiles', 77],
#  ['Heating,Cooling&AirQuality', 116],
#  ['Lapdesks', 14],
# ...

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage rating rating_count  \
# 0        1099.0                 0.64    4.2        24269
# ...

# %%
df_pr = pd.DataFrame(data,columns=['category','freq'])

# %%
df_pr.sort_values(by='freq',ascending=False)
# Out:
#                     category  freq
# 127              Accessories   888
# 282              Electronics   530
# 24     Computers&Accessories   451
# 77              Home&Kitchen   448
# 257  Accessories&Peripherals   379
# ..                       ...   ...
# 126         EspressoMachines     1
# 125          HandlebarMounts     1
# 124             SelfieLights     1
# 123              LaundryBags     1
# 316    AirPurifiers&Ionizers     1
#
# [317 rows x 2 columns]

# %%
df_pr = df.sort_values(by='rating_count',ascending = False)

# %%
df_pr.head()
# Out:
#       product_id                                       product_name  \
# 861   B07S7DCJKS  IT2M Designer Mouse Pad for Laptop/Computer (9...
# 754   B07Z1X6VFC  AirCase Protective Laptop Bag Sleeve fits Upto...
# 1279  B08L12N5H1  Eureka Forbes car Vac 100 Watts Powerful Sucti...
# 750   B00ZRBWPA0       Eveready Red 1012 AAA Batteries - Pack of 10
# 977   B083T5G5PM  Sennheiser CX 80S in-Ear Wired Headphones with...
#
#                                                category  discounted_price  \
# 861   Computers&Accessories|Accessories&Peripherals|...             199.0
# 754   Computers&Accessories|Accessories&Peripherals|...             449.0
# 1279  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...            2099.0
# 750   Electronics|GeneralPurposeBatteries&BatteryCha...             159.0
# 977   Electronics|Headphones,Earbuds&Accessories|Hea...            1490.0
#
#       actual_price  discount_percentage rating rating_count  \
# ...

# %%
df_pr = df.sort_values(by='discounted_price',ascending = False)
df_pr.head()
# Out:
#      product_id                                       product_name  \
# 249  B09WN3SRC7  Sony Bravia 164 cm (65 inches) 4K Ultra HD Sma...
# 325  B095JPKPH3  OnePlus 163.8 cm (65 inches) U Series 4K LED S...
# 255  B0BC8BQ432  VU 164 cm (65 inches) The GloLED Series 4K Sma...
# 192  B0B15GSPQW  Samsung 138 cm (55 inches) Crystal 4K Neo Seri...
# 283  B0B3XXSB1K  LG 139 cm (55 inches) 4K Ultra HD Smart LED TV...
#
#                                               category  discounted_price  \
# 249  Electronics|HomeTheater,TV&Video|Televisions|S...           77990.0
# 325  Electronics|HomeTheater,TV&Video|Televisions|S...           61999.0
# 255  Electronics|HomeTheater,TV&Video|Televisions|S...           54990.0
# 192  Electronics|HomeTheater,TV&Video|Televisions|S...           47990.0
# 283  Electronics|HomeTheater,TV&Video|Televisions|S...           47990.0
#
#      actual_price  discount_percentage rating rating_count  \
# 249      139900.0                 0.44    4.7         5935
# ...
